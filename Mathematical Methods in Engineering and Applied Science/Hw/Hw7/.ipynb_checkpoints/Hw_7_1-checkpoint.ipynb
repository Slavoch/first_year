# %%
import scipy 
from scipy.optimize import linprog
import numpy as np

# %%
c = [1,1]
A_ub1 = [[-1,-1]]
b_ub1 = [[-6]]
linprog(c=c,A_ub=A_ub1,b_ub=b_ub1)
# Out:
#      con: array([], dtype=float64)
#      fun: 6.000000000001678
#  message: 'Optimization terminated successfully.'
#      nit: 4
#    slack: array([1.67776903e-12])
#   status: 0
#  success: True
#        x: array([3., 3.])

# %%
c = [1,1]
A = -1*np.array([
    [2,1],
    [2,2],
    [1,2],
    [-3,1],
    [1,-3]
])
b = -1*np.array([2,3,2,-6,-6])

solut = linprog(c = c, A_ub = A, b_ub = b)

# %%
solut
# Out:
#      con: array([], dtype=float64)
#      fun: 1.5000000000042775
#  message: 'Optimization terminated successfully.'
#      nit: 5
#    slack: array([2.50000000e-01, 8.55493454e-12, 2.50000000e-01, 4.50000000e+00,
#        4.50000000e+00])
#   status: 0
#  success: True
#        x: array([0.75, 0.75])

# %%
import sympy as sp
from sympy.plotting import plot

x1, x2 = sp.symbols('x_1 x_2')
p1 = plot(2 - 2*x1, 3/2 - x1,1 - 1/2 *x1,-6 + 3*x1,2 + 1/3 *x1,(x1,-1/2,3.4),show = False)
p1.legend = True
p1.ylim = (0,3)
p1.show()

# %%
import scipy.optimize
x = np.arange(1,25)
y = np.array([75,77,76,73,69,68,63,59,57,55,54,52,50,50,49,49,49,50,54,56,59,63,67,72])

Fit = np.array([x**3,x**2,x,x**0]).transpose()
Y = y.transpose()

error = lambda u: np.linalg.norm(Y - Fit @ u,2)
scipy.optimize.fmin(func = error, x0=[1,1,1,60])
# Out:
# Optimization terminated successfully.
#          Current function value: 6.123091
#          Iterations: 451
#          Function evaluations: 757
# array([ 9.18552584e-03, -1.59522492e-01, -1.74893782e+00,  8.02351658e+01])

# %%
U_sol = np.linalg.pinv(Fit) @ Y

# %%
error(U_sol)
# Out:
# 6.123091284927192

# %%
from numpy.random import randn

weight = 30
mutations = lambda n: randn(n,4) * weight

m  = 1000
n  = 50
n2 = 10
U_0 = np.array([1,1,1,60] *n).reshape(n,4)


U = U_0
E = np.zeros(n)
E_hist=[]
for jgen in range(m):
    for j in range(n):
        E[j] = error(U[j])
    sortIndexes = np.argsort(E)
    BestGen = U[sortIndexes[:n2]]
    nextGen = BestGen
    nextGen_mut = np.vstack((BestGen,BestGen,BestGen,BestGen)) + mutations(n-n2)/ (jgen+1)
    U = np.vstack((nextGen,nextGen_mut))
    E_hist.append(E[sortIndexes[0]])
print(E[0])
print(U[0])
# Out:
# 22.58717664746225
# [ 2.46703264e-02 -7.83815255e-01  5.33783425e+00  6.09311042e+01]

# %%
U
# Out:
# array([[ 2.90458622e-02, -9.22894399e-01,  6.13839235e+00,
#        [ 8.74291570e-02, -8.75843510e-01,  6.21040188e+00,
#          6.39747414e+01],
#        [ 3.54069736e-02, -9.01044728e-01,  6.14183987e+00,
#          6.37420120e+01],
#        [ 9.71311174e-02, -8.94347040e-01,  6.20231675e+00,
#          6.37464411e+01],
#        [ 4.57668128e-03, -8.79894605e-01,  6.28395016e+00,
#          6.38299217e+01],
#        [ 8.75615307e-02, -9.19436743e-01,  6.24650568e+00,
#          6.37243925e+01],
#        [ 4.67107594e-02, -9.09810674e-01,  6.22263000e+00,
#          6.38968748e+01],
#        [ 3.22567396e-02, -9.30332033e-01,  6.23989827e+00,
#          6.37218165e+01],
#        [-6.46159841e-04, -9.63007570e-01,  6.11262329e+00,
#          6.40175653e+01],
#        [ 5.35720919e-02, -9.23246042e-01,  6.15065412e+00,
#          6.39932724e+01],
#        [ 3.33914160e-02, -8.64778918e-01,  6.28094224e+00,
#          6.38016202e+01],
#        [ 4.90617319e-03, -9.00013584e-01,  6.22986750e+00,
#          6.40516168e+01],
#        [ 1.35234985e-03, -9.62655875e-01,  6.12617911e+00,
#          6.37615057e+01],
#        [-3.29872065e-02, -9.22339179e-01,  6.22616846e+00,
#          6.37064272e+01],
#        [-6.69870966e-03, -9.19767508e-01,  6.24637517e+00,
#          6.37733052e+01],
#        [ 9.51255818e-02, -9.51833727e-01,  6.20579581e+00,
#          6.36756341e+01],
#        [ 9.78711873e-02, -9.10722035e-01,  6.22738683e+00,
#          6.39225786e+01],
#        [ 3.97599369e-02, -9.40570691e-01,  6.20210983e+00,
#          6.37579161e+01],
#        [ 6.23388423e-02, -8.77177403e-01,  6.18551476e+00,
#          6.40284287e+01],
#        [ 2.42780758e-02, -9.34125445e-01,  6.14582953e+00,
#          6.40505155e+01],
#        [ 9.87476650e-02, -9.05337221e-01,  6.27858524e+00,
#          6.37839451e+01],
#        [ 3.19218705e-02, -9.20644959e-01,  6.22162601e+00,
#          6.40834648e+01]])

# %%
import matplotlib.pyplot as plt
plt.plot(E_hist)

# %%
E[27]
# Out:
# 652063.9522165426

# %%
U_0[sortIndexes[:n2]]
# Out:
# array([[  0.48505282,  -8.08230981, -15.32843386,  48.75529702],
#        [ -0.58364969,   5.99556101,  -5.97912574,  69.83356315],
#        [  0.31158887,  13.89747365,  20.28423695,  43.74414961],
#        [  1.        ,   1.        ,   1.        ,  60.        ],
#        [  1.        ,   1.        ,   1.        ,  60.        ],
#        [  1.        ,   1.        ,   1.        ,  60.        ],
#        [  1.        ,   1.        ,   1.        ,  60.        ],
#        [  1.        ,   1.        ,   1.        ,  60.        ],
#        [  1.        ,   1.        ,   1.        ,  60.        ],
#        [  1.        ,   1.        ,   1.        ,  60.        ]])
